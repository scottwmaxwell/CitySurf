# %%
import pandas as pd

file_path = '../data/city_market_tracker.tsv000'
chunk_size = 100000

# Read the header separately
header = pd.read_csv(file_path, delimiter='\t', nrows=10).columns

header
# Out:
# Index(['period_begin', 'period_end', 'period_duration', 'region_type',
#        'region_type_id', 'table_id', 'is_seasonally_adjusted', 'region',
#        'city', 'state', 'state_code', 'property_type', 'property_type_id',
#        'median_sale_price', 'median_sale_price_mom', 'median_sale_price_yoy',
#        'median_list_price', 'median_list_price_mom', 'median_list_price_yoy',
#        'median_ppsf', 'median_ppsf_mom', 'median_ppsf_yoy', 'median_list_ppsf',
#        'median_list_ppsf_mom', 'median_list_ppsf_yoy', 'homes_sold',
#        'homes_sold_mom', 'homes_sold_yoy', 'pending_sales',
#        'pending_sales_mom', 'pending_sales_yoy', 'new_listings',
#        'new_listings_mom', 'new_listings_yoy', 'inventory', 'inventory_mom',
#        'inventory_yoy', 'months_of_supply', 'months_of_supply_mom',
#        'months_of_supply_yoy', 'median_dom', 'median_dom_mom',
#        'median_dom_yoy', 'avg_sale_to_list', 'avg_sale_to_list_mom',
# ...

# %%
df = pd.read_csv(file_path, delimiter='\t')

# %%
df
# Out:
#         period_begin  period_end  period_duration region_type  region_type_id  \
# 0         2016-05-01  2016-05-31               30       place               6
# 1         2019-06-01  2019-06-30               30       place               6
# 2         2013-11-01  2013-11-30               30       place               6
# 3         2018-10-01  2018-10-31               30       place               6
# 4         2022-02-01  2022-02-28               30       place               6
# ...              ...         ...              ...         ...             ...
# 5484738   2015-10-01  2015-10-31               30       place               6
# 5484739   2018-12-01  2018-12-31               30       place               6
# 5484740   2016-10-01  2016-10-31               30       place               6
# 5484741   2016-01-01  2016-01-31               30       place               6
# 5484742   2023-08-01  2023-08-31               30       place               6
#
# ...

# %%
flornce_az =  df[(df['city'] == 'Florence') & (df['state'] == "Arizona") & (df['property_type'] == "Single Family Residential")].copy()
#[['city', 'state', 'period_begin', 'period_end', 'median_sale_price']]
flornce_az['period_begin'] = pd.to_datetime(df['period_begin'])
flornce_az_sorted = flornce_az.sort_values(by='period_begin')

# %%
flornce_az_sorted.to_csv('./florence_az_test.csv')

# %%
unique_combinations_count = df.groupby(['city', 'state']).size().count()
print(f"Number of unique city-state combinations: {unique_combinations_count}")
# Out:
# Number of unique city-state combinations: 22903

# %%
df[(df['city'] == 'Florence') & (df['state'] == "Arizona")]
# Out:
#         period_begin  period_end  period_duration region_type  region_type_id  \
# 1359      2016-05-01  2016-05-31               30       place               6
# 2781      2020-11-01  2020-11-30               30       place               6
# 32172     2019-03-01  2019-03-31               30       place               6
# 33647     2016-10-01  2016-10-31               30       place               6
# 49091     2012-03-01  2012-03-31               30       place               6
# ...              ...         ...              ...         ...             ...
# 5445116   2018-07-01  2018-07-31               30       place               6
# 5457316   2013-03-01  2013-03-31               30       place               6
# 5464234   2015-11-01  2015-11-30               30       place               6
# 5465001   2015-06-01  2015-06-30               30       place               6
# 5477234   2022-09-01  2022-09-30               30       place               6
#
# ...

# %%
city_state = pd.DataFrame()

# %%
# Drop duplicates to create a new DataFrame with unique city-state pairs
unique_cities_df = df.drop_duplicates(subset=['city', 'state'])

# Select only the 'city' and 'state' columns
unique_cities_df = unique_cities_df[['city', 'state']]

# Reset the index of the resulting DataFrame
unique_cities_df = unique_cities_df.reset_index(drop=True)
# Out:
#                                   city          state
# 0                           Morgandale           Ohio
# 1                               Durant       Oklahoma
# 2      Village of Oak Creek (Big Park)        Arizona
# 3                        Lake Lotawana       Missouri
# 4                      Seaside Heights     New Jersey
# ...                                ...            ...
# 22898                        McConnico        Arizona
# 22899                            Mosby       Virginia
# 22900                          Schwana     Washington
# 22901                         Toad Hop        Indiana
# 22902                           Beaver  West Virginia
#
# [22903 rows x 2 columns]

# %%
unique_cities_df.to_csv('./city_state.csv')
